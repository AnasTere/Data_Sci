# %% [markdown]
# <a href="https://colab.research.google.com/github/AnasTere/Data_Sci/blob/main/Anastasia_Tereschenko_22_Lab_6_Cereal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import urllib.request

# %%
urllib.request.urlretrieve('https://raw.githubusercontent.com/williamedwardhahn/Probability_Statistics/main/cereal_data.csv','cereal_data.csv')
# Out:
# ('cereal_data.csv', <http.client.HTTPMessage at 0x7f03d7d3d640>)

# %%
cereal_data = pd.read_csv('cereal_data.csv')

# %% [markdown]
# Name: Name of cereal
#
# mfr: Manufacturer of cereal
#
#     A = American Home Food Products
#
#     G = General Mills
#
#     K = Kelloggs
#
#     N = Nabisco
#
#     P = Post
#
#     Q = Quaker Oats
#
#     R = Ralston Purina
#
# type:
#
#     cold
#
#     hot
#
# calories: calories per serving
#
# protein: grams of protein
#
# fat: grams of fat
#
# sodium: milligrams of sodium
#
# fiber: grams of dietary fiber
#
# carbo: grams of complex carbohydrates
#
# sugars: grams of sugars
#
# potass: milligrams of potassium
#
# vitamins: vitamins and minerals - 0, 25, or 100,
# indicating the typical percentage of FDA recommended
#
# shelf: display shelf (1, 2, or 3, counting from the floor)
#
# weight: weight in ounces of one serving
#
# cups: number of cups in one serving
#
# rating: a rating of the cereals

# %%
cereal_data
# Out:
#                          name mfr type  calories  protein  fat  sodium  fiber  \
# 0                   100% Bran   N    C        70        4    1     130   10.0
# 1           100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                    All-Bran   K    C        70        4    1     260    9.0
# 3   All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4              Almond Delight   R    C       110        2    2     200    1.0
# ..                        ...  ..  ...       ...      ...  ...     ...    ...
# 72                    Triples   G    C       110        2    1     250    0.0
# 73                       Trix   G    C       110        1    1     140    0.0
# 74                 Wheat Chex   R    C       100        3    1     230    3.0
# 75                   Wheaties   G    C       100        3    1     200    3.0
# 76        Wheaties Honey Gold   G    C       110        2    1     200    1.0
#
# ...

# %%
cereal_data["sugars"].mean() #finds the mean of the amount of sugars in the cereal in grams
# Out:
# 6.922077922077922

# %%
cereal_data[["calories", "sugars"]].mean() #finds the mean of calories and sugars
# Out:
# calories    106.883117
# sugars        6.922078
# dtype: float64

# %%
cereal_data.describe() #shows all data
# Out:
#          calories    protein        fat      sodium      fiber      carbo  \
# count   77.000000  77.000000  77.000000   77.000000  77.000000  77.000000
# mean   106.883117   2.545455   1.012987  159.675325   2.151948  14.597403
# std     19.484119   1.094790   1.006473   83.832295   2.383364   4.278956
# min     50.000000   1.000000   0.000000    0.000000   0.000000  -1.000000
# 25%    100.000000   2.000000   0.000000  130.000000   1.000000  12.000000
# 50%    110.000000   3.000000   1.000000  180.000000   2.000000  14.000000
# 75%    110.000000   3.000000   2.000000  210.000000   3.000000  17.000000
# max    160.000000   6.000000   5.000000  320.000000  14.000000  23.000000
#
#           sugars      potass    vitamins      shelf     weight       cups  \
# count  77.000000   77.000000   77.000000  77.000000  77.000000  77.000000
# mean    6.922078   96.077922   28.246753   2.207792   1.029610   0.821039
# std     4.444885   71.286813   22.342523   0.832524   0.150477   0.232716
# ...

# %%
cereal_data[["calories", "sugars"]] #displays calories and suagrs for all cerelas
# Out:
#     calories  sugars
# 0         70       6
# 1        120       8
# 2         70       5
# 3         50       0
# 4        110       8
# ..       ...     ...
# 72       110       3
# 73       110      12
# 74       100       3
# 75       100       3
# 76       110       8
#
# [77 rows x 2 columns]

# %%
plt.plot(cereal_data[["sugars"]],cereal_data[["calories"]],'.') #plots cereal data sugars and calories

# %%
plt.plot(cereal_data[["fat"]],cereal_data[["calories"]],'.') # plots fat and calories

# %%
plt.plot(cereal_data[["fat"]],cereal_data[["calories"]],'.')

# %%
plt.plot(cereal_data[["sugars"]],cereal_data[["carbo"]],'.') #plots sugar and cards

# %%
plt.plot(cereal_data[["sugars"]],cereal_data[["vitamins"]],'.') #plots sugars and viatmins

# %%
X = cereal_data[["sugars"]] #stores suagrs in X 
Y = cereal_data[["calories"]] #stores calories in y

# %%
from sklearn.linear_model import LinearRegression
linear_regressor = LinearRegression()

# %%
linear_regressor.fit(X, Y)
Y_pred = linear_regressor.predict(X)

# %%
plt.plot(X, Y,'.') #finds line of best fit for caloreis and sugar 
plt.plot(X, Y_pred, color='red')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(0,10,50)

# %%
noise = 10 * np.random.randn(50,)

# %%
y = 3 * x + 7 + noise

# %%
plt.plot(x,y,'.');

# %%
m_guess = 1 #trying to find line of best fit, undershot 
b_guess = 1

y_guess = m_guess * x + b_guess

plt.plot(x,y_guess,'r.');
plt.plot(x,y,'g.');

# %%
m_guess = 5 #trying to find line of best fit, overshot 
b_guess = 15

y_guess = m_guess * x + b_guess

plt.plot(x,y_guess,'r.');
plt.plot(x,y,'g.');

# %%
m_guess = 3 #trying to find line of best fit correct 
b_guess = 7

y_guess = m_guess * x + b_guess

plt.plot(x,y_guess,'r.');
plt.plot(x,y,'g.');

# %%
loss = np.sum((y_guess - y)**2)

# %%
loss
# Out:
# 3850.7025857874473

# %%
for m_guess in np.linspace(-10,10,10): #for loops to find the line of best fit for the data 
    for b_guess in np.linspace(-10,10,10):
        
        y_guess = m_guess * x + b_guess

        plt.plot(x,y_guess,'r.');
        plt.plot(x,y,'g.');
        plt.show()

        loss = np.sum((y_guess - y)**2)

        print(loss,m_guess,b_guess)
# Out:
# 412490.78861987684 -10.0 -10.0
# 394588.0333730951 -10.0 -7.777777777777778
# 377179.1052868073 -10.0 -5.555555555555555
# 360264.00436101324 -10.0 -3.333333333333333
# 343842.730595713 -10.0 -1.1111111111111107
# 327915.2839909066 -10.0 1.1111111111111107
# 312481.66454659414 -10.0 3.333333333333334
# 297541.8722627753 -10.0 5.555555555555557
# 283095.9071394504 -10.0 7.777777777777779
# 269143.76917661936 -10.0 10.0
# 304687.9715170498 -7.777777777777778 -10.0
# 289254.3520727372 -7.777777777777778 -7.777777777777778
# 274314.5597889185 -7.777777777777778 -5.555555555555555
# 259868.59466559358 -7.777777777777778 -3.333333333333333
# 245916.45670276252 -7.777777777777778 -1.1111111111111107
# 232458.14590042527 -7.777777777777778 1.1111111111111107
# 219493.6622585818 -7.777777777777778 3.333333333333334
# 207023.0057772322 -7.777777777777778 5.555555555555557
# 195046.17645637647 -7.777777777777778 7.777777777777779
# 183563.1742960145 -7.777777777777778 10.0
# ...

# %%
best_loss = 100000 #stops when finds line of best fit
best_m = 0
best_b = 0 

for m_guess in np.linspace(-10,10,20):
    for b_guess in np.linspace(-10,10,20):
        
        y_guess = m_guess * x + b_guess

        loss = np.sum((y_guess - y)**2)

        if loss < best_loss:
            
            best_loss = loss
            best_m = m_guess
            best_b = b_guess 

            plt.plot(x,y_guess,'r.');
            plt.plot(x,y,'g.');
            plt.show()

            print(loss,m_guess,b_guess)
# Out:
# 97177.22043137658 -4.736842105263158 8.94736842105263
# 93399.95348006938 -4.736842105263158 10.0
# 90446.13921350721 -3.6842105263157894 3.6842105263157894
# 86668.87226220002 -3.6842105263157894 4.7368421052631575
# 83002.40863499256 -3.6842105263157894 5.789473684210526
# 79446.74833188484 -3.6842105263157894 6.842105263157894
# 76001.89135287682 -3.6842105263157894 7.894736842105264
# 72667.83769796854 -3.6842105263157894 8.94736842105263
# 69444.58736715997 -3.6842105263157894 10.0
# 66897.80571973964 -2.6315789473684212 3.6842105263157894
# 63674.55538893108 -2.6315789473684212 4.7368421052631575
# 60562.10838222224 -2.6315789473684212 5.789473684210526
# 57560.46469961312 -2.6315789473684212 6.842105263157894
# 54669.62434110372 -2.6315789473684212 7.894736842105264
# 51889.587306694055 -2.6315789473684212 8.94736842105263
# 49220.3535963841 -2.6315789473684212 10.0
# 47080.60456810561 -1.578947368421053 3.6842105263157894
# ...
